# %% [markdown]
# <a href="https://colab.research.google.com/github/simmonsnev/gis-project-portfolio-geo441-541b/blob/main/spatial-analysis/simmonnh_spatial_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Vector Data / Spatial Analysis**

# %% [markdown]
# Created by Nev Simmons
#
# 10/29/25

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ## **Part 1: John Snow Cholera Maps**
#
# ---

# %% [markdown]
# ### **1a: Water Pump Buffer Map**

# %% [markdown]
# Below is a map of cholera deaths inside a 100m buffer of water pumps in the Soho District of London, 1854.
#
# ```markdown
# https://drive.google.com/file/d/1h1UY4_Zh-Rt6h6BjMWc56b45CQJuQCnu/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1h1UY4_Zh-Rt6h6BjMWc56b45CQJuQCnu
#
# ```
#
#
#
# <mark>![pump buffer](https://drive.google.com/uc?export=view&id=1h1UY4_Zh-Rt6h6BjMWc56b45CQJuQCnu)</mark>

# %% [markdown]
# ### **1b: Cholera Deaths Heatmap**

# %% [markdown]
# Below is a heatmap of cholera deaths in the Soho District of London, 1854.
#
# ```markdown
# https://drive.google.com/file/d/1VMI60BHMHbxAr0JBhzPfmHX_5eAM_Aq8/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1VMI60BHMHbxAr0JBhzPfmHX_5eAM_Aq8
# ```
#
#
# <mark>![heatmap](https://drive.google.com/uc?export=view&id=1VMI60BHMHbxAr0JBhzPfmHX_5eAM_Aq8)</mark>

# %% [markdown]
# ## **Part 2: Campgrounds**
#
# ---

# %% [markdown]
# Below is a map of sites suitable for campgrounds on private land near Hugo Lake, MN.
#
# ```markdown
# https://drive.google.com/file/d/1BRxM4aW7OPTmr8elS1aV54bKyn77F_xF/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1BRxM4aW7OPTmr8elS1aV54bKyn77F_xF
# ```
#
#
#
# <mark>![private land](https://drive.google.com/uc?export=view&id=1BRxM4aW7OPTmr8elS1aV54bKyn77F_xF)</mark>

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 10 Assignment.**</mark>
